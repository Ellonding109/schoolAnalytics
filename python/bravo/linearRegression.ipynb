# %%
import numpy as np 
from sklearn.linear_model import LinearRegression

# %%
x = np.array([1,0,2,0,3,1,0,1,2,0])
y = np.array([16,9,17,12,22,13,8,15,19,11])

# Calculation of te function 
#mean of x and y

x_bar = np.mean(x)
print(f"mean of x: {x_bar}")
y_bar = np.mean(y)
print(f"mean of y: {y_bar}")
# Out:
# mean of x: 1.0
# mean of y: 14.2

# %%
# now the actual culculation given finding beta0 and beta1
b1 = np.sum((x - x_bar)*(y - y_bar)) / np.sum((x - x_bar)**2) 
print(b1)
# Out:
# 4.0

# %%
names = np.array(("Alex","bravo","fidel"))
names[[-1]]
# Out:
# array(['fidel'], dtype='<U5')

# %%
class linear:
    def __init__(self,radius,height):
        self.radius = radius
        self.height = height
        def calculate():
